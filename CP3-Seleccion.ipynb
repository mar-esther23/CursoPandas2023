# %% [markdown]
# # Análisis y visualización de datos con python
# # 3. Indexación y selección de dataframes
#
#     - a) Estructura de una tabla
#     - b) Slicing
#     - c) Únicos y conteo
#     - d) Ordenar
#     - e) Subsetting
#     - f) Guardar datos
#
# ---

# %% [markdown]
# ## 3.a Estructura de una tabla
#
# En primer lugar cargaremos las primeras mil lineas del Módulo de Fosas Comunes como vimos en el tutorial anterior.
#
# Adicionalmente, marcaremos que la columna `ID` es el indice de la tabla usando la opción `index_col`. El indice debé de ser único, es decir, los valores no deben de repetirse.
#
# Incluiremos un comando de limpieza, los cuales explicaremos en otro momento.

# %%
import pandas as pd

file_mfc = 'data_raw/Modulo-de-Fosas-Comunes_actualizacion24nov2022_VD.xlsx'
df = pd.read_excel(file_mfc, #nombre del archivo definido en la variable file_mfc
                   sheet_name="MFC", #nombre de la hoja
                   nrows=1000, #número de filas que se leeran
                   index_col='ID' #nombre de la columna del indice
                  )
df['Edad'] = pd.to_numeric(df['Edad'], errors='coerce') #Limpieza
df
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P002   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P996   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001   Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P002   Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003   Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004   Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P996   Inhumación       2018-09-01                  S/D              NaT
# XX-P997   Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P999   Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#               Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001   Restos cremados  Masculino  55.0          Desconocido
# XX-P002           Cadáver  Masculino   NaN          Desconocido
# XX-P003           Cadáver  Masculino   NaN             Conocido
# XX-P004           Cadáver  Masculino   NaN          Desconocido
# XX-P005           Cadáver  Masculino   NaN          Desconocido
# ...                   ...        ...   ...                  ...
# XX-P996           Cadáver  Masculino  42.0             Conocido
# XX-P997           Cadáver  Masculino  64.0             Conocido
# XX-P998           Cadáver  Masculino   NaN          Desconocido
# XX-P999           Cadáver   Femenino   1.0          Desconocido
# XX-P1000          Cadáver  Masculino   NaN          Desconocido
#
#          Primer apellido Segundo Apellido    Nombre(s)  \
# ID
# XX-P001              NaN              NaN          NaN
# XX-P002              NaN              NaN          NaN
# XX-P003             Cruz           Lucero      Alberto
# XX-P004              NaN              NaN          NaN
# XX-P005              NaN              NaN          NaN
# ...                  ...              ...          ...
# XX-P996           Flores          Rosette       Sergio
# XX-P997           Juárez           Chávez  Juan Carlos
# XX-P998              NaN              NaN          NaN
# XX-P999              NaN              NaN          NaN
# XX-P1000             NaN              NaN          NaN
#
#                     Nombre completo  \
# ID
# XX-P001
# XX-P002
# XX-P003         Alberto Cruz Lucero
# XX-P004
# XX-P005
# ...                             ...
# XX-P996       Sergio Flores Rosette
# XX-P997   Juan Carlos Juárez Chávez
# XX-P998
# XX-P999
# XX-P1000
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P001         UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P002   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                     ...  ...
# XX-P996   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P001  2020-03-23 00:00:00.000                 NaN
# XX-P002  2020-03-23 00:00:00.000                 NaN
# XX-P003  2020-03-23 00:00:00.000                 NaN
# XX-P004  2020-03-23 00:00:00.000                 NaN
# XX-P005  2020-03-23 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P996  2020-04-06 21:19:52.451                 NaN
# XX-P997  2020-04-06 21:22:53.304                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P999  2020-04-06 21:32:30.839                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# Una tabla de pandas o dataframe consta de varios elementos:
# * Nombres de columnas, las cuales pueden ser vistas como la primera fila en letras negritas. Para verlas usa _.columns_.
# * Nombres de filas, las cuales pueden ser vistas como la primera columna, la cual carece de nombre. Para verlas usa _.index_.
# * Valores, los datos dentro de la tabla. Para verlas usa _.values_.
# * El número de filas y columnas total. Para verla usa _.shape_.
# * Tipo de datos de cada columna. Para verla usa _.dtype_.

# %% [markdown]
# Con el fin de conocer el nombre de las columnas usaremos la opción _.columns_. Es importante notar que esta opción no tiene paréntesis no corchetes, ya que es un elemento del objeto.

# %%
df.columns
# Out:
# Index(['Estado_origen', 'Municipio_origen', 'Panteón_origen', 'Estatus_FC',
#        'Fecha_inhumación', 'Fecha_defunción', 'Fecha_exhumación',
#        'Restos_tipo', 'Sexo', 'Edad', 'Conocido_Desconocido',
#        'Primer apellido', 'Segundo Apellido', 'Nombre(s)', 'Nombre completo',
#        'Institución_origen', 'Rdoc', 'Marca_temporal', 'Datos alternativos'],
#       dtype='object')

# %% [markdown]
# Estas columnas corresponden a las del diccionario de datos que se encuentra en la Hoja 2 del archivo.
#
# ### Ejercicio 1
#
# Usa cada una de las opciones mencionadas en esta sección y describe que regresa.
# * `df.index`
# * `df.values`
# * `df.shape`
# * `df.dtypes`

# %%
df.shape
# Out:
# (1000, 19)

# %% [markdown]
# ## 3.b Slicing
#
# Muchas veces no queremos trabajar sobre toda la tabla de datos, en su lugar queremos usar unicamente una fracción de ella. Para ello, existen varias formas de selecionar partes de una tabla.
#
# Por ejemplo, la función _.head()_ devuelve las primeras filas de la tabla. Por defecto estos comandos muestran solo cinco filas, pero es posible cambiar el número de filas poniendo un número entre paréntesis.

# %%
df.head()
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P002  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001  Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P002  Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003  Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004  Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
#
#              Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001  Restos cremados  Masculino  55.0          Desconocido
# XX-P002          Cadáver  Masculino   NaN          Desconocido
# XX-P003          Cadáver  Masculino   NaN             Conocido
# XX-P004          Cadáver  Masculino   NaN          Desconocido
# XX-P005          Cadáver  Masculino   NaN          Desconocido
#
#         Primer apellido Segundo Apellido Nombre(s)      Nombre completo  \
# ID
# XX-P001             NaN              NaN       NaN
# XX-P002             NaN              NaN       NaN
# XX-P003            Cruz           Lucero   Alberto  Alberto Cruz Lucero
# XX-P004             NaN              NaN       NaN
# XX-P005             NaN              NaN       NaN
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P001        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P002  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#         Marca_temporal  Datos alternativos
# ID
# XX-P001     2020-03-23                 NaN
# XX-P002     2020-03-23                 NaN
# XX-P003     2020-03-23                 NaN
# XX-P004     2020-03-23                 NaN
# XX-P005     2020-03-23                 NaN

# %% [markdown]
# Si queremos ver las últimas filas se puede usar el comando _.tail()_.
#
# En ambos casos se puede específicar el número de filas que se quieren ver

# %%
df.tail( 10 )
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P991   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P992   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P993   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P994   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P995   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P996   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P991   Inhumación       2018-09-01  2017-10-06 00:00:00              NaT
# XX-P992   Inhumación       2018-09-01  2017-10-09 00:00:00              NaT
# XX-P993   Inhumación       2018-09-01  2017-10-16 00:00:00              NaT
# XX-P994   Inhumación       2018-09-01                  S/D              NaT
# XX-P995   Inhumación       2018-09-01                  S/D              NaT
# XX-P996   Inhumación       2018-09-01                  S/D              NaT
# XX-P997   Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P999   Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#          Restos_tipo       Sexo  Edad Conocido_Desconocido Primer apellido  \
# ID
# XX-P991      Cadáver  Masculino  55.0          Desconocido             NaN
# XX-P992      Cadáver  Masculino  50.0          Desconocido             NaN
# XX-P993      Cadáver  Masculino  50.0          Desconocido             NaN
# XX-P994      Cadáver  Masculino  65.0             Conocido         Ramirez
# XX-P995      Cadáver  Masculino  31.0             Conocido             NaN
# XX-P996      Cadáver  Masculino  42.0             Conocido          Flores
# XX-P997      Cadáver  Masculino  64.0             Conocido          Juárez
# XX-P998      Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P999      Cadáver   Femenino   1.0          Desconocido             NaN
# XX-P1000     Cadáver  Masculino   NaN          Desconocido             NaN
#
#          Segundo Apellido    Nombre(s)            Nombre completo  \
# ID
# XX-P991               NaN          NaN
# XX-P992               NaN          NaN
# XX-P993               NaN          NaN
# XX-P994               NaN         José              José Ramirez
# XX-P995               NaN      Luciano                  Luciano
# XX-P996           Rosette       Sergio      Sergio Flores Rosette
# XX-P997            Chávez  Juan Carlos  Juan Carlos Juárez Chávez
# XX-P998               NaN          NaN
# XX-P999               NaN          NaN
# XX-P1000              NaN          NaN
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P991   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P992   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P993   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P994   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P995   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P996   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P991  2020-04-06 21:01:48.076                 NaN
# XX-P992  2020-04-06 21:03:54.636                 NaN
# XX-P993  2020-04-06 21:05:50.156                 NaN
# XX-P994  2020-04-06 21:10:54.850                 NaN
# XX-P995  2020-04-06 21:17:19.389                 NaN
# XX-P996  2020-04-06 21:19:52.451                 NaN
# XX-P997  2020-04-06 21:22:53.304                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P999  2020-04-06 21:32:30.839                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN

# %% [markdown]
# Para ver una columna específica se pone el nombre del dataframe seguido por corchetes con el nombre de la columna. Una sola columna es del tipo _series_. Por ejemplo, para ver la columna del sexo ponemos su nombre 'Sexo' entre corchetes. Esto es similar a la forma en la que se seleccionan elementos en listas o diccionarios.

# %%
df[ 'Sexo' ]
# Out:
# ID
# XX-P001     Masculino
# XX-P002     Masculino
# XX-P003     Masculino
# XX-P004     Masculino
# XX-P005     Masculino
#               ...
# XX-P996     Masculino
# XX-P997     Masculino
# XX-P998     Masculino
# XX-P999      Femenino
# XX-P1000    Masculino
# Name: Sexo, Length: 1000, dtype: object

# %% [markdown]
# Se pueden seleccionar varias columnas a la vez, poniendo sus nombres en una lista dentro de corchetes. Lo anterior significa que para seleccionar varias columnas hay que usar corchetes dobles.

# %%
df[  ['Conocido_Desconocido','Sexo']  ]
# Out:
#          Conocido_Desconocido       Sexo
# ID
# XX-P001           Desconocido  Masculino
# XX-P002           Desconocido  Masculino
# XX-P003              Conocido  Masculino
# XX-P004           Desconocido  Masculino
# XX-P005           Desconocido  Masculino
# ...                       ...        ...
# XX-P996              Conocido  Masculino
# XX-P997              Conocido  Masculino
# XX-P998           Desconocido  Masculino
# XX-P999           Desconocido   Femenino
# XX-P1000          Desconocido  Masculino
#
# [1000 rows x 2 columns]

# %% [markdown]
# La primera columna que podemos observar en la tabla y carece de nombre, es el índice de las filas.
# Por default, pandas asigna números de identificación a cada una de las filas, empezando por el cero .
# Sin embargo, es posible especificar que columna es el indice cómo se vió al principio del tutorial.
#
# Podemos seleccionar las filas por posición o por el nombren el indice.
# Con `.iloc` se selecciona el número de posición de la fila, sin olvidar que la numeración empieza en 0. Por ejemplo, seleccionemos la novena fila.

# %%
df.iloc[9]
# Out:
# Estado_origen                                            Ciudad de México
# Municipio_origen                                           Miguel Hidalgo
# Panteón_origen                                   Panteón Civil de Dolores
# Estatus_FC                                                     Inhumación
# Fecha_inhumación                                      2019-01-26 00:00:00
# Fecha_defunción                                       2018-12-18 00:00:00
# Fecha_exhumación                                                      NaT
# Restos_tipo                                                       Cadáver
# Sexo                                                            Masculino
# Edad                                                                  NaN
# Conocido_Desconocido                                          Desconocido
# Primer apellido                                                       NaN
# Segundo Apellido                                                      NaN
# Nombre(s)                                                             NaN
# Nombre completo
# Institución_origen      INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...
# Rdoc                                                                   Sí
# Marca_temporal                                        2020-03-23 00:00:00
# Datos alternativos                                                    NaN
# Name: XX-P010, dtype: object

# %% [markdown]
# De la misma manera, se pueden seleccionar varias filas usando una lista.

# %%
df.iloc[  [9, 13, 62, 201]  ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P010  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P014  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P063  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P202  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P010  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P014  Inhumación       2019-01-26  2018-12-19 00:00:00              NaT
# XX-P063  Inhumación       2019-01-12  2018-11-29 00:00:00              NaT
# XX-P202  Inhumación       2018-10-20  2018-09-18 00:00:00              NaT
#
#         Restos_tipo       Sexo  Edad Conocido_Desconocido Primer apellido  \
# ID
# XX-P010     Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P014     Cadáver   Femenino   NaN             Conocido          Ibarra
# XX-P063     Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P202     Cadáver   Femenino   NaN             Conocido         Aguirre
#
#         Segundo Apellido Nombre(s)       Nombre completo  \
# ID
# XX-P010              NaN       NaN
# XX-P014           García     Wendy   Wendy Ibarra García
# XX-P063              NaN       NaN
# XX-P202           Bahena     Delia  Delia Aguirre Bahena
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P010  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P014  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P063  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P202  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#         Marca_temporal  Datos alternativos
# ID
# XX-P010     2020-03-23                 NaN
# XX-P014     2020-03-23                 NaN
# XX-P063     2020-03-24                 NaN
# XX-P202     2020-03-24                 NaN

# %% [markdown]
# O se puede marcar una secuencia de posiciones como si fuera una lista

# %%
df.iloc[  5:10  ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P006  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P007  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P008  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P009  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P010  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P006  Inhumación       2019-01-26  2018-12-16 00:00:00              NaT
# XX-P007  Inhumación       2019-01-26  2018-12-16 00:00:00              NaT
# XX-P008  Inhumación       2019-01-26  2019-12-17 00:00:00              NaT
# XX-P009  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P010  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
#
#         Restos_tipo       Sexo  Edad Conocido_Desconocido Primer apellido  \
# ID
# XX-P006     Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P007     Cadáver  Masculino   NaN             Conocido             NaN
# XX-P008     Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P009     Cadáver  Masculino   NaN             Conocido         Cordero
# XX-P010     Cadáver  Masculino   NaN          Desconocido             NaN
#
#         Segundo Apellido Nombre(s)   Nombre completo  \
# ID
# XX-P006              NaN       NaN
# XX-P007              NaN    Miguel          Miguel
# XX-P008              NaN       NaN
# XX-P009              NaN   Rolando  Rolando Cordero
# XX-P010              NaN       NaN
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P006  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P007  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P008  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P009  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P010  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#         Marca_temporal  Datos alternativos
# ID
# XX-P006     2020-03-23                 NaN
# XX-P007     2020-03-23                 NaN
# XX-P008     2020-03-23                 NaN
# XX-P009     2020-03-23                 NaN
# XX-P010     2020-03-23                 NaN

# %% [markdown]
# Este comando también se puede usar para seleccionar un conjunto de filas y columnas específico usando la posición. Para hacerlo se utiliza el formato: `df.iloc[filas, columnas]`.

# %%
df.iloc[ 9:15, [2,5,7] ]
# Out:
#                    Panteón_origen      Fecha_defunción Restos_tipo
# ID
# XX-P010  Panteón Civil de Dolores  2018-12-18 00:00:00     Cadáver
# XX-P011  Panteón Civil de Dolores  2018-12-18 00:00:00     Cadáver
# XX-P012  Panteón Civil de Dolores  2018-12-30 00:00:00     Cadáver
# XX-P013  Panteón Civil de Dolores  2018-12-21 00:00:00     Cadáver
# XX-P014  Panteón Civil de Dolores  2018-12-19 00:00:00     Cadáver
# XX-P015  Panteón Civil de Dolores  2018-12-23 00:00:00     Cadáver

# %% [markdown]
# Con `.loc` (sin la **i**) se selecciona la llave de la fila.

# %%
df.loc[ 'XX-P010' ]
# Out:
# Estado_origen                                            Ciudad de México
# Municipio_origen                                           Miguel Hidalgo
# Panteón_origen                                   Panteón Civil de Dolores
# Estatus_FC                                                     Inhumación
# Fecha_inhumación                                      2019-01-26 00:00:00
# Fecha_defunción                                       2018-12-18 00:00:00
# Fecha_exhumación                                                      NaT
# Restos_tipo                                                       Cadáver
# Sexo                                                            Masculino
# Edad                                                                  NaN
# Conocido_Desconocido                                          Desconocido
# Primer apellido                                                       NaN
# Segundo Apellido                                                      NaN
# Nombre(s)                                                             NaN
# Nombre completo
# Institución_origen      INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...
# Rdoc                                                                   Sí
# Marca_temporal                                        2020-03-23 00:00:00
# Datos alternativos                                                    NaN
# Name: XX-P010, dtype: object

# %% [markdown]
# Este comando también se puede usar para seleccionar un conjunto de filas y columnas específico por la llave o el nombre en el indice y las columnas. Para hacerlo se utiliza el formato: _df.loc[filas, columnas]_

# %%
df.loc[  ['XX-P010', 'XX-P013', 'XX-P062', 'XX-P201']  , ['Conocido_Desconocido','Sexo']  ]
# Out:
#         Conocido_Desconocido       Sexo
# ID
# XX-P010          Desconocido  Masculino
# XX-P013          Desconocido  Masculino
# XX-P062             Conocido  Masculino
# XX-P201             Conocido  Masculino

# %% [markdown]
# ## 3.c Únicos y conteo
#
# Se pueden hacer varias cosas con una columna o `series`.
#
# Por ejemplo, se pueden determinar los valores únicos de la columna para entender la información contenida en ella.
#
# Por ejemplo, al revisar el profile se puede ver que hay múltiples instituciones de origen, así que obtendremos una lista de estas.

# %%
df['Institución_origen'].unique()
# Out:
# array(['UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA',
#        'INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPERIOR DE JUSTICIA DE LA CIUDAD DE MÉXICO',
#        'UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE MEDICINA CIENCIAS BÁSICAS',
#        'INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIONAL DE MEDICINA Y HOMEOPATÍA',
#        'CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA',
#        'UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACULTAD DE MEDICINA',
#        'UNIVERSIDAD ANÁHUAC - FACULTAD DE CIENCIAS DE LA SALUD',
#        'ESCUELA DE MEDICINA SAINT LUKE',
#        'INSTITUCIÓN DE ASISTENCIA PRIVADA - ESCUELA LIBRE DE HOMEOPATÍA DE MÉXICO',
#        'SECRETARÍA DE LA DEFENSA NACIONAL - ESCUELA MILITAR DE MEDICINA',
#        'THE AMERICAN BRITISH COWDRAY MEDICAL CENTER LA.P.',
#        'PROCURADURÍA GENERAL DE LA REPÚBLICA',
#        'UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA'], dtype=object)

# %% [markdown]
# Si lo único que nos interesa saber es cuantos datos únicos hay, y no cuales son, se puede usar la función _.nunique()_.

# %%
df['Institución_origen'].nunique()
# Out:
# 13

# %% [markdown]
# También, se puede contabilizar cuántas veces aparece cada uno de estos valores. Esto permite saber cuantas veces aparece cada valor único. El resultado de la función es un dataframe.

# %%
df['Institución_origen'].value_counts()
# Out:
# INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPERIOR DE JUSTICIA DE LA CIUDAD DE MÉXICO    533
# UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACULTAD DE MEDICINA                           331
# INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIONAL DE MEDICINA Y HOMEOPATÍA                58
# CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA                                                16
# UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA                                               15
# UNIVERSIDAD ANÁHUAC - FACULTAD DE CIENCIAS DE LA SALUD                                    13
# THE AMERICAN BRITISH COWDRAY MEDICAL CENTER LA.P.                                          9
# SECRETARÍA DE LA DEFENSA NACIONAL - ESCUELA MILITAR DE MEDICINA                            7
# UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA                                          7
# UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE MEDICINA CIENCIAS BÁSICAS                    4
# ESCUELA DE MEDICINA SAINT LUKE                                                             4
# PROCURADURÍA GENERAL DE LA REPÚBLICA                                                       2
# INSTITUCIÓN DE ASISTENCIA PRIVADA - ESCUELA LIBRE DE HOMEOPATÍA DE MÉXICO                  1
# Name: Institución_origen, dtype: int64

# %% [markdown]
# Para ver estos resultados como porcentaje se puede usar el parámetro _normalize_.

# %%
df['Institución_origen'].value_counts( normalize=True )
# Out:
# INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPERIOR DE JUSTICIA DE LA CIUDAD DE MÉXICO    0.533
# UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACULTAD DE MEDICINA                           0.331
# INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIONAL DE MEDICINA Y HOMEOPATÍA               0.058
# CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA                                               0.016
# UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA                                              0.015
# UNIVERSIDAD ANÁHUAC - FACULTAD DE CIENCIAS DE LA SALUD                                   0.013
# THE AMERICAN BRITISH COWDRAY MEDICAL CENTER LA.P.                                        0.009
# SECRETARÍA DE LA DEFENSA NACIONAL - ESCUELA MILITAR DE MEDICINA                          0.007
# UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA                                        0.007
# UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE MEDICINA CIENCIAS BÁSICAS                  0.004
# ESCUELA DE MEDICINA SAINT LUKE                                                           0.004
# PROCURADURÍA GENERAL DE LA REPÚBLICA                                                     0.002
# INSTITUCIÓN DE ASISTENCIA PRIVADA - ESCUELA LIBRE DE HOMEOPATÍA DE MÉXICO                0.001
# Name: Institución_origen, dtype: float64

# %% [markdown]
# Es posible usar la función `value_counts` sobre varias columnas a la vez.
# Esto regrese un dataframe con un `multi index`.

# %%
df[ ['Sexo','Conocido_Desconocido'] ].value_counts()
# Out:
# Sexo           Conocido_Desconocido
# Masculino      Conocido                440
#                Desconocido             378
# Femenino       Conocido                136
#                Desconocido              33
# Indeterminado  Desconocido              10
#                Conocido                  3
# dtype: int64

# %% [markdown]
# Es posible que en una columna o variable haya filas u observaciones donde no se registro el dato.
# Para incluir los NaN es necesario cambiar los parámetros de la función,usando el parámetro `dropna=False`.
# Esto es de suma importancia al normalizar los datos, ya que el porcentaje de cada valor único cambiará dependiendo de si se toman, o no, en cuenta los NaN.

# %%
df['Edad'].value_counts(normalize=True ,  dropna=False, )
# Out:
# NaN      0.460
# 50.0     0.021
# 60.0     0.020
# 40.0     0.019
# 70.0     0.018
#          ...
# 97.0     0.001
# 101.0    0.001
# 6.0      0.001
# 44.0     0.001
# 1.0      0.001
# Name: Edad, Length: 89, dtype: float64

# %% [markdown]
# Como el resultado de la función `value_counts` es un dataframe podemos utilizar funciones propias de dataframe como `head` o slicing.
#
# Por ejemplo, para ver las cinco instituciones que entregan más cadaveres obtendremos el conteo de valores con _.value_counts()_ y después seleccionaremos los cinco primeros usando un slicing de lista.

# %%
df['Institución_origen'].value_counts().head(5)
# Out:
# INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPERIOR DE JUSTICIA DE LA CIUDAD DE MÉXICO    533
# UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACULTAD DE MEDICINA                           331
# INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIONAL DE MEDICINA Y HOMEOPATÍA                58
# CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA                                                16
# UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA                                               15
# Name: Institución_origen, dtype: int64

# %% [markdown]
# ### Ejercicio 2
#
# * ¿Cuáles son los cinco apellidos más comunes?
# * ¿Cuántas veces aparece cada uno?
# * ¿Qué porcentaje de la población tiene cada apellido? ¿Es lo mismo si normalizamos?
# * ¿Cómo afectan los datos protegidos por razones legales estas cuentas?

# %% [markdown]
# ## 3.d Ordenar
#
# Además de poder seleccionar los datos muchas veces es muy importante poder ordenarlos. Para eso usaremos _.sort_values()_
#
# Para ordenar una sola columna:

# %%
df['Nombre(s)'].sort_values()
# Out:
# ID
# XX-P822       Abel
# XX-P019      Adela
# XX-P130     Adolfo
# XX-P478     Adrian
# XX-P073     Adrian
#              ...
# XX-P992        NaN
# XX-P993        NaN
# XX-P998        NaN
# XX-P999        NaN
# XX-P1000       NaN
# Name: Nombre(s), Length: 1000, dtype: object

# %% [markdown]
# Por default _.sort_values()_ ordena en orden alfábetico o de menor a mayor, en caso de datos númericos.
# Para cambiar esto podemos usar el parámetro _ascending_. Por default los datos con NaN siempre van al final de la tabla.
# Es importante destacar que los acentos pueden causar problemas al ordenar alfabeticamente.

# %%
df['Nombre(s)'].sort_values( ascending=False )
# Out:
# ID
# XX-P896        Ángel
# XX-P595       Ándres
# XX-P587       Ándres
# XX-P641     Zeferino
# XX-P426         Yair
#               ...
# XX-P992          NaN
# XX-P993          NaN
# XX-P998          NaN
# XX-P999          NaN
# XX-P1000         NaN
# Name: Nombre(s), Length: 1000, dtype: object

# %% [markdown]
# Para ordenar todo el dataframe por una columna es necesario decir explicitamente que columna se va a usar.
#
# Nota como en ambos casos se selecciona primero sobre que se va a trabajar, ya sea el dataframe completo (`df`) o una columna específica (`df[nombre_columna]`), después se dice que se va a hacer con el nombre de la función (`.sort_values()`) y finalmente se dan instrucciones específicas a la función de cómo hacerlo si es necesario poniendo los parametros dentro del parentesis.

# %%
df.sort_values( 'Nombre(s)' )
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P822   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P019   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P130   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P478   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P073   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P992   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P993   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P822   Inhumación       2018-07-07  2015-01-30 00:00:00              NaT
# XX-P019   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P130   Inhumación       2018-12-07  2018-03-09 00:00:00              NaT
# XX-P478   Inhumación       2019-03-30  2016-12-17 00:00:00              NaT
# XX-P073   Inhumación       2019-01-02  2017-09-20 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P992   Inhumación       2018-09-01  2017-10-09 00:00:00              NaT
# XX-P993   Inhumación       2018-09-01  2017-10-16 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P999   Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#               Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P822   Restos cremados  Masculino  32.0             Conocido
# XX-P019           Cadáver   Femenino   NaN             Conocido
# XX-P130           Cadáver  Masculino  89.0             Conocido
# XX-P478   Restos cremados  Masculino  73.0             Conocido
# XX-P073           Cadáver  Masculino  89.0             Conocido
# ...                   ...        ...   ...                  ...
# XX-P992           Cadáver  Masculino  50.0          Desconocido
# XX-P993           Cadáver  Masculino  50.0          Desconocido
# XX-P998           Cadáver  Masculino   NaN          Desconocido
# XX-P999           Cadáver   Femenino   1.0          Desconocido
# XX-P1000          Cadáver  Masculino   NaN          Desconocido
#
#          Primer apellido Segundo Apellido Nombre(s)           Nombre completo  \
# ID
# XX-P822            Reyes          Vázquez      Abel        Abel Reyes Vázquez
# XX-P019         Martínez        Hernández     Adela  Adela Martínez Hernández
# XX-P130           Méndez             Vaca    Adolfo        Adolfo Méndez Vaca
# XX-P478          Palafox            Muñoz    Adrian      Adrian Palafox Muñoz
# XX-P073          Ramirez           Molina    Adrian     Adrian Ramirez Molina
# ...                  ...              ...       ...                       ...
# XX-P992              NaN              NaN       NaN
# XX-P993              NaN              NaN       NaN
# XX-P998              NaN              NaN       NaN
# XX-P999              NaN              NaN       NaN
# XX-P1000             NaN              NaN       NaN
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P822   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P019   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P130   INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# XX-P478   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P073   INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# ...                                                     ...  ...
# XX-P992   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P993   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P822  2020-04-02 13:45:06.218                 NaN
# XX-P019  2020-03-23 00:00:00.000                 NaN
# XX-P130  2020-03-24 00:00:00.000                 NaN
# XX-P478  2020-03-30 12:15:50.000                 NaN
# XX-P073  2020-03-24 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P992  2020-04-06 21:03:54.636                 NaN
# XX-P993  2020-04-06 21:05:50.156                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P999  2020-04-06 21:32:30.839                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# Es posible ordenar por varias columnas especificando el nombre de las columnas en una lista y la forma de ordenarlas usando _ascending_.

# %%
df.sort_values(  ['Sexo', 'Edad', 'Conocido_Desconocido']  ,  ascending=True   )
df
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P002   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P996   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001   Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P002   Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003   Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004   Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P996   Inhumación       2018-09-01                  S/D              NaT
# XX-P997   Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P999   Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#               Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001   Restos cremados  Masculino  55.0          Desconocido
# XX-P002           Cadáver  Masculino   NaN          Desconocido
# XX-P003           Cadáver  Masculino   NaN             Conocido
# XX-P004           Cadáver  Masculino   NaN          Desconocido
# XX-P005           Cadáver  Masculino   NaN          Desconocido
# ...                   ...        ...   ...                  ...
# XX-P996           Cadáver  Masculino  42.0             Conocido
# XX-P997           Cadáver  Masculino  64.0             Conocido
# XX-P998           Cadáver  Masculino   NaN          Desconocido
# XX-P999           Cadáver   Femenino   1.0          Desconocido
# XX-P1000          Cadáver  Masculino   NaN          Desconocido
#
#          Primer apellido Segundo Apellido    Nombre(s)  \
# ID
# XX-P001              NaN              NaN          NaN
# XX-P002              NaN              NaN          NaN
# XX-P003             Cruz           Lucero      Alberto
# XX-P004              NaN              NaN          NaN
# XX-P005              NaN              NaN          NaN
# ...                  ...              ...          ...
# XX-P996           Flores          Rosette       Sergio
# XX-P997           Juárez           Chávez  Juan Carlos
# XX-P998              NaN              NaN          NaN
# XX-P999              NaN              NaN          NaN
# XX-P1000             NaN              NaN          NaN
#
#                     Nombre completo  \
# ID
# XX-P001
# XX-P002
# XX-P003         Alberto Cruz Lucero
# XX-P004
# XX-P005
# ...                             ...
# XX-P996       Sergio Flores Rosette
# XX-P997   Juan Carlos Juárez Chávez
# XX-P998
# XX-P999
# XX-P1000
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P001         UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P002   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                     ...  ...
# XX-P996   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P001  2020-03-23 00:00:00.000                 NaN
# XX-P002  2020-03-23 00:00:00.000                 NaN
# XX-P003  2020-03-23 00:00:00.000                 NaN
# XX-P004  2020-03-23 00:00:00.000                 NaN
# XX-P005  2020-03-23 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P996  2020-04-06 21:19:52.451                 NaN
# XX-P997  2020-04-06 21:22:53.304                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P999  2020-04-06 21:32:30.839                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# ## 3.e Subsetting
#
# Es posible seleccionar los datos de acuerdo a una (o más) condición.
#
# Por ejemplo para seleccionar todos los delitos que afectan a mujeres buscamos las filas donde el 'Sexo' es 'Femenino' con la condición:

# %%
df['Sexo'] == 'Femenino'
# Out:
# ID
# XX-P001     False
# XX-P002     False
# XX-P003     False
# XX-P004     False
# XX-P005     False
#             ...
# XX-P996     False
# XX-P997     False
# XX-P998     False
# XX-P999      True
# XX-P1000    False
# Name: Sexo, Length: 1000, dtype: bool

# %% [markdown]
# Esta condicion nos dice para cada fila si el valos es 'Femenino', si ponemos esto dentro de _.loc[]_ podemos usarlo para encontrar las filas de víctimas de mujeres.

# %%
df.loc[ df['Sexo']=='Femenino' ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P014  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P019  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P027  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P034  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P037  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P953  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P956  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P967  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P968  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P014  Inhumación       2019-01-26  2018-12-19 00:00:00              NaT
# XX-P019  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P027  Inhumación       2019-01-26                  S/D              NaT
# XX-P034  Inhumación       2019-01-19  2018-12-04 00:00:00              NaT
# XX-P037  Inhumación       2019-01-19  2018-12-07 00:00:00              NaT
# ...             ...              ...                  ...              ...
# XX-P953  Inhumación       2018-07-14  2017-09-04 00:00:00              NaT
# XX-P956  Inhumación       2018-07-14  2018-06-09 00:00:00              NaT
# XX-P967  Inhumación       2018-07-14  2017-08-08 00:00:00              NaT
# XX-P968  Inhumación       2018-07-14  2017-07-21 00:00:00              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#         Restos_tipo      Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P014     Cadáver  Femenino   NaN             Conocido
# XX-P019     Cadáver  Femenino   NaN             Conocido
# XX-P027    Miembros  Femenino  35.0             Conocido
# XX-P034     Cadáver  Femenino   NaN          Desconocido
# XX-P037     Cadáver  Femenino   NaN             Conocido
# ...             ...       ...   ...                  ...
# XX-P953     Cadáver  Femenino   NaN          Desconocido
# XX-P956     Cadáver  Femenino   NaN             Conocido
# XX-P967     Cadáver  Femenino   NaN          Desconocido
# XX-P968     Cadáver  Femenino   NaN             Conocido
# XX-P999     Cadáver  Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P014                                             Ibarra
# XX-P019                                           Martínez
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                           González
# ...                                                    ...
# XX-P953                                                NaN
# XX-P956                                      Martha Helida
# XX-P967                                                NaN
# XX-P968                                             Gaytan
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P014                                             García
# XX-P019                                          Hernández
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                              Valle
# ...                                                    ...
# XX-P953                                                NaN
# XX-P956                                              Silva
# XX-P967                                                NaN
# XX-P968                                            Ramirez
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P014                                              Wendy
# XX-P019                                              Adela
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                             Gloria
# ...                                                    ...
# XX-P953                                                NaN
# XX-P956                                            Morales
# XX-P967                                                NaN
# XX-P968                                            Marysol
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P014                                Wendy Ibarra García
# XX-P019                           Adela Martínez Hernández
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034
# XX-P037                              Gloria González Valle
# ...                                                    ...
# XX-P953
# XX-P956                        Morales Martha Helida Silva
# XX-P967
# XX-P968                             Marysol Gaytan Ramirez
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P014  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P019  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P027  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P034  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P037  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                    ...  ...
# XX-P953  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P956  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P967  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P968  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P014 2020-03-23 00:00:00.000                 NaN
# XX-P019 2020-03-23 00:00:00.000                 NaN
# XX-P027 2020-03-23 00:00:00.000                 NaN
# XX-P034 2020-03-23 00:00:00.000                 NaN
# XX-P037 2020-03-23 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P953 2020-04-06 09:41:05.347                 NaN
# XX-P956 2020-04-06 11:09:46.318                 NaN
# XX-P967 2020-04-06 15:14:11.685                 NaN
# XX-P968 2020-04-06 15:17:22.421                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN
#
# [169 rows x 19 columns]

# %% [markdown]
# Para seleccionar los delitos que NO afectan a las mujeres buscamos aquellos donde el sexo es diferenente (_!=_) a 'Femenino'

# %%
df[  df['Sexo'] != 'Femenino'  ]
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P002   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P995   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P996   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001   Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P002   Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003   Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004   Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P995   Inhumación       2018-09-01                  S/D              NaT
# XX-P996   Inhumación       2018-09-01                  S/D              NaT
# XX-P997   Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#               Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001   Restos cremados  Masculino  55.0          Desconocido
# XX-P002           Cadáver  Masculino   NaN          Desconocido
# XX-P003           Cadáver  Masculino   NaN             Conocido
# XX-P004           Cadáver  Masculino   NaN          Desconocido
# XX-P005           Cadáver  Masculino   NaN          Desconocido
# ...                   ...        ...   ...                  ...
# XX-P995           Cadáver  Masculino  31.0             Conocido
# XX-P996           Cadáver  Masculino  42.0             Conocido
# XX-P997           Cadáver  Masculino  64.0             Conocido
# XX-P998           Cadáver  Masculino   NaN          Desconocido
# XX-P1000          Cadáver  Masculino   NaN          Desconocido
#
#          Primer apellido Segundo Apellido    Nombre(s)  \
# ID
# XX-P001              NaN              NaN          NaN
# XX-P002              NaN              NaN          NaN
# XX-P003             Cruz           Lucero      Alberto
# XX-P004              NaN              NaN          NaN
# XX-P005              NaN              NaN          NaN
# ...                  ...              ...          ...
# XX-P995              NaN              NaN      Luciano
# XX-P996           Flores          Rosette       Sergio
# XX-P997           Juárez           Chávez  Juan Carlos
# XX-P998              NaN              NaN          NaN
# XX-P1000             NaN              NaN          NaN
#
#                     Nombre completo  \
# ID
# XX-P001
# XX-P002
# XX-P003         Alberto Cruz Lucero
# XX-P004
# XX-P005
# ...                             ...
# XX-P995                   Luciano
# XX-P996       Sergio Flores Rosette
# XX-P997   Juan Carlos Juárez Chávez
# XX-P998
# XX-P1000
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P001         UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P002   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                     ...  ...
# XX-P995   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P996   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P001  2020-03-23 00:00:00.000                 NaN
# XX-P002  2020-03-23 00:00:00.000                 NaN
# XX-P003  2020-03-23 00:00:00.000                 NaN
# XX-P004  2020-03-23 00:00:00.000                 NaN
# XX-P005  2020-03-23 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P995  2020-04-06 21:17:19.389                 NaN
# XX-P996  2020-04-06 21:19:52.451                 NaN
# XX-P997  2020-04-06 21:22:53.304                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [831 rows x 19 columns]

# %% [markdown]
# Si los datos son numéricos es posible usar operaciones como mayor, menor o igual para seleccionar con esas condiciones. Por ejemplo para ver los cadaveres menor de edad podriamos buscar todos las filas donde el valor de la edad es menor que 18.
#
# **Nota** Al cargar los datos en la primera celda de código se limpio la celda para que solo incluyera valores numéricos, lo cuál se explicará en otro tutorial

# %%
df[  df['Edad']<18  ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P461  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P481  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P484  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P586  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P781  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P784  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P876  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P882  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P969  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P461  Inhumación       2019-02-16                  S/D              NaT
# XX-P481  Inhumación       2019-02-02                  S/D              NaT
# XX-P484  Inhumación       2019-05-18                  S/D              NaT
# XX-P586  Inhumación       2019-03-16                  S/D              NaT
# XX-P781  Inhumación       2017-10-14                  S/D              NaT
# XX-P784  Inhumación       2017-10-14                  S/D              NaT
# XX-P876  Inhumación       2018-09-29                  S/D              NaT
# XX-P882  Inhumación       2018-09-29                  S/D              NaT
# XX-P969  Inhumación       2018-07-14                  S/D              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#             Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P461  Restos humanos   Femenino  15.0             Conocido
# XX-P481        Miembros  Masculino  13.0             Conocido
# XX-P484        Miembros   Femenino   6.0             Conocido
# XX-P586        Miembros  Masculino  13.0             Conocido
# XX-P781  Restos humanos  Masculino  17.0             Conocido
# XX-P784  Restos humanos  Masculino  16.0             Conocido
# XX-P876        Miembros  Masculino  11.0             Conocido
# XX-P882        Miembros  Masculino  11.0             Conocido
# XX-P969        Miembros  Masculino   5.0             Conocido
# XX-P999         Cadáver   Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P461  Nombre de particular que se encuentra con vida...
# XX-P481  Nombre de particular que se encuentra con vida...
# XX-P484  Nombre de particular que se encuentra con vida...
# XX-P586  Nombre de particular que se encuentra con vida...
# XX-P781  Nombre de particular que se encuentra con vida...
# XX-P784  Nombre de particular que se encuentra con vida...
# XX-P876  Nombre de particular que se encuentra con vida...
# XX-P882  Nombre de particular que se encuentra con vida...
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P461  Nombre de particular que se encuentra con vida...
# XX-P481  Nombre de particular que se encuentra con vida...
# XX-P484  Nombre de particular que se encuentra con vida...
# XX-P586  Nombre de particular que se encuentra con vida...
# XX-P781  Nombre de particular que se encuentra con vida...
# XX-P784  Nombre de particular que se encuentra con vida...
# XX-P876  Nombre de particular que se encuentra con vida...
# XX-P882  Nombre de particular que se encuentra con vida...
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P461  Nombre de particular que se encuentra con vida...
# XX-P481  Nombre de particular que se encuentra con vida...
# XX-P484  Nombre de particular que se encuentra con vida...
# XX-P586  Nombre de particular que se encuentra con vida...
# XX-P781  Nombre de particular que se encuentra con vida...
# XX-P784  Nombre de particular que se encuentra con vida...
# XX-P876  Nombre de particular que se encuentra con vida...
# XX-P882  Nombre de particular que se encuentra con vida...
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P461  Nombre de particular que se encuentra con vida...
# XX-P481  Nombre de particular que se encuentra con vida...
# XX-P484  Nombre de particular que se encuentra con vida...
# XX-P586  Nombre de particular que se encuentra con vida...
# XX-P781  Nombre de particular que se encuentra con vida...
# XX-P784  Nombre de particular que se encuentra con vida...
# XX-P876  Nombre de particular que se encuentra con vida...
# XX-P882  Nombre de particular que se encuentra con vida...
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P461  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P481  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P484  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P586  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P781  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P784  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P876  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P882  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P969  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P461 2020-03-30 11:46:31.000                 NaN
# XX-P481 2020-03-30 12:19:13.000                 NaN
# XX-P484 2020-03-30 12:25:05.000                 NaN
# XX-P586 2020-03-30 16:39:26.000                 NaN
# XX-P781 2020-02-04 11:04:39.000                 NaN
# XX-P784 2020-02-04 11:14:33.000                 NaN
# XX-P876 2020-04-03 13:43:18.417                 NaN
# XX-P882 2020-04-03 14:46:48.721                 NaN
# XX-P969 2020-04-06 17:53:48.782                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN

# %% [markdown]
# En varios casos podemos ver que no hay datos sobre el edad del cadaver, lo cual se representa con _NaN_. Para ver las filas con valor _NaN_ se usa la función _isna()_.
#
# Lo anterior puede representar un problema al momento del análisis, ya que significa que los datos son incompletos y generalmente es necesario procesarlos como veremos mas adelante. Es por esto que es importante revisar los faltantes.

# %%
df[  df['Edad'].isna()  ]
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P002   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P006   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P968   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P974   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P978   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P002   Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003   Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004   Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P006   Inhumación       2019-01-26  2018-12-16 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P968   Inhumación       2018-07-14  2017-07-21 00:00:00              NaT
# XX-P974   Inhumación       2018-07-14                  S/D              NaT
# XX-P978   Inhumación       2018-07-17  2018-01-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#              Restos_tipo           Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P002          Cadáver      Masculino   NaN          Desconocido
# XX-P003          Cadáver      Masculino   NaN             Conocido
# XX-P004          Cadáver      Masculino   NaN          Desconocido
# XX-P005          Cadáver      Masculino   NaN          Desconocido
# XX-P006          Cadáver      Masculino   NaN          Desconocido
# ...                  ...            ...   ...                  ...
# XX-P968          Cadáver       Femenino   NaN             Conocido
# XX-P974   Restos humanos  Indeterminado   NaN          Desconocido
# XX-P978          Cadáver      Masculino   NaN          Desconocido
# XX-P998          Cadáver      Masculino   NaN          Desconocido
# XX-P1000         Cadáver      Masculino   NaN          Desconocido
#
#          Primer apellido Segundo Apellido Nombre(s)         Nombre completo  \
# ID
# XX-P002              NaN              NaN       NaN
# XX-P003             Cruz           Lucero   Alberto     Alberto Cruz Lucero
# XX-P004              NaN              NaN       NaN
# XX-P005              NaN              NaN       NaN
# XX-P006              NaN              NaN       NaN
# ...                  ...              ...       ...                     ...
# XX-P968           Gaytan          Ramirez   Marysol  Marysol Gaytan Ramirez
# XX-P974              NaN              NaN       NaN
# XX-P978              NaN              NaN       NaN
# XX-P998              NaN              NaN       NaN
# XX-P1000             NaN              NaN       NaN
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P002   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P006   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                     ...  ...
# XX-P968   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P974   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P978          CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P002  2020-03-23 00:00:00.000                 NaN
# XX-P003  2020-03-23 00:00:00.000                 NaN
# XX-P004  2020-03-23 00:00:00.000                 NaN
# XX-P005  2020-03-23 00:00:00.000                 NaN
# XX-P006  2020-03-23 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P968  2020-04-06 15:17:22.421                 NaN
# XX-P974  2020-04-06 18:51:06.834                 NaN
# XX-P978  2020-04-06 19:53:36.113                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [460 rows x 19 columns]

# %% [markdown]
# Es posible hacer lo contrario a la instrucción de selección agregando una negación al principio del comando de selección.
#
# Por ejemplo, para seleccionar las observaciones donde SI hay una edad, seleccionamos aquellas que no tienen Edad con isna() y luego las negamos. Recuerda que dos negaciones son una afirmación.

# %%
df[ ~ df['Edad'].isna() ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P024  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P025  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P026  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P027  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P994  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P995  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P996  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001  Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P024  Inhumación       2019-01-26                  S/D              NaT
# XX-P025  Inhumación       2019-01-26                  S/D              NaT
# XX-P026  Inhumación       2019-01-26                  S/D              NaT
# XX-P027  Inhumación       2019-01-26                  S/D              NaT
# ...             ...              ...                  ...              ...
# XX-P994  Inhumación       2018-09-01                  S/D              NaT
# XX-P995  Inhumación       2018-09-01                  S/D              NaT
# XX-P996  Inhumación       2018-09-01                  S/D              NaT
# XX-P997  Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#              Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001  Restos cremados  Masculino  55.0          Desconocido
# XX-P024         Miembros  Masculino  31.0             Conocido
# XX-P025         Miembros  Masculino  18.0             Conocido
# XX-P026         Miembros  Masculino  39.0             Conocido
# XX-P027         Miembros   Femenino  35.0             Conocido
# ...                  ...        ...   ...                  ...
# XX-P994          Cadáver  Masculino  65.0             Conocido
# XX-P995          Cadáver  Masculino  31.0             Conocido
# XX-P996          Cadáver  Masculino  42.0             Conocido
# XX-P997          Cadáver  Masculino  64.0             Conocido
# XX-P999          Cadáver   Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P001                                                NaN
# XX-P024  Nombre de particular que se encuentra con vida...
# XX-P025  Nombre de particular que se encuentra con vida...
# XX-P026  Nombre de particular que se encuentra con vida...
# XX-P027  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P994                                            Ramirez
# XX-P995                                                NaN
# XX-P996                                             Flores
# XX-P997                                             Juárez
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P001                                                NaN
# XX-P024  Nombre de particular que se encuentra con vida...
# XX-P025  Nombre de particular que se encuentra con vida...
# XX-P026  Nombre de particular que se encuentra con vida...
# XX-P027  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P994                                                NaN
# XX-P995                                                NaN
# XX-P996                                            Rosette
# XX-P997                                             Chávez
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P001                                                NaN
# XX-P024  Nombre de particular que se encuentra con vida...
# XX-P025  Nombre de particular que se encuentra con vida...
# XX-P026  Nombre de particular que se encuentra con vida...
# XX-P027  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P994                                               José
# XX-P995                                            Luciano
# XX-P996                                             Sergio
# XX-P997                                        Juan Carlos
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P001
# XX-P024  Nombre de particular que se encuentra con vida...
# XX-P025  Nombre de particular que se encuentra con vida...
# XX-P026  Nombre de particular que se encuentra con vida...
# XX-P027  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P994                                      José Ramirez
# XX-P995                                          Luciano
# XX-P996                              Sergio Flores Rosette
# XX-P997                          Juan Carlos Juárez Chávez
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P001        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P024  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P025  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P026  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P027  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                    ...  ...
# XX-P994  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P995  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P996  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P001 2020-03-23 00:00:00.000                 NaN
# XX-P024 2020-03-23 00:00:00.000                 NaN
# XX-P025 2020-03-23 00:00:00.000                 NaN
# XX-P026 2020-03-23 00:00:00.000                 NaN
# XX-P027 2020-03-23 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P994 2020-04-06 21:10:54.850                 NaN
# XX-P995 2020-04-06 21:17:19.389                 NaN
# XX-P996 2020-04-06 21:19:52.451                 NaN
# XX-P997 2020-04-06 21:22:53.304                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN
#
# [540 rows x 19 columns]

# %% [markdown]
# A veces no queremos seleccionar las columnas que tienen un solo valor, sino varios. Por ejemplo, si queremos ver los restos que provienen de instituciones educativas privadas podemos generar una lista llamada 'escuelas_privadas' y despues los buscamos con el comando _.isin()_

# %%
escuelas_privadas = ['CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA', 'UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA', 
                     'UNIVERSIDAD ANÁHUAC - FACULTAD DE CIENCIAS DE LA SALUD', 'THE AMERICAN BRITISH COWDRAY MEDICAL CENTER LA.P.', 
                     'UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA', 'UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE MEDICINA CIENCIAS BÁSICAS', 
                     'ESCUELA DE MEDICINA SAINT LUKE', 'INSTITUCIÓN DE ASISTENCIA PRIVADA - ESCUELA LIBRE DE HOMEOPATÍA DE MÉXICO']
df[ df['Institución_origen'].isin(escuelas_privadas) ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P001  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P048  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P091  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P092  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P093  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P983  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P984  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P985  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P986  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P987  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P001  Inhumación       2019-01-30  2018-03-04 00:00:00              NaT
# XX-P048  Inhumación       2019-01-16  2018-03-03 00:00:00              NaT
# XX-P091  Inhumación       2018-12-14  2018-02-27 00:00:00              NaT
# XX-P092  Inhumación       2018-12-14  2018-03-22 00:00:00              NaT
# XX-P093  Inhumación       2018-12-14  2018-06-14 00:00:00              NaT
# ...             ...              ...                  ...              ...
# XX-P983  Inhumación       2018-07-18  2017-06-29 00:00:00              NaT
# XX-P984  Inhumación       2018-07-18  2017-09-05 00:00:00              NaT
# XX-P985  Inhumación       2018-07-18  2017-10-02 00:00:00              NaT
# XX-P986  Inhumación       2018-07-18  2017-10-05 00:00:00              NaT
# XX-P987  Inhumación       2017-07-28  2016-09-29 00:00:00              NaT
#
#              Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P001  Restos cremados  Masculino  55.0          Desconocido
# XX-P048          Cadáver  Masculino  74.0             Conocido
# XX-P091          Cadáver  Masculino  40.0          Desconocido
# XX-P092          Cadáver  Masculino  40.0          Desconocido
# XX-P093          Cadáver  Masculino  40.0          Desconocido
# ...                  ...        ...   ...                  ...
# XX-P983          Cadáver  Masculino  56.0             Conocido
# XX-P984          Cadáver  Masculino  57.0             Conocido
# XX-P985          Cadáver  Masculino  38.0          Desconocido
# XX-P986          Cadáver  Masculino  70.0          Desconocido
# XX-P987          Cadáver  Masculino  65.0          Desconocido
#
#         Primer apellido Segundo Apellido  Nombre(s)         Nombre completo  \
# ID
# XX-P001             NaN              NaN        NaN
# XX-P048          García        Hernández      Pedro  Pedro García Hernández
# XX-P091             NaN              NaN        NaN
# XX-P092             NaN              NaN        NaN
# XX-P093             NaN              NaN        NaN
# ...                 ...              ...        ...                     ...
# XX-P983             NaN              NaN  Francisco             Francisco
# XX-P984           Gómez          Sánchez   Fernando  Fernando Gómez Sánchez
# XX-P985             NaN              NaN        NaN
# XX-P986             NaN              NaN        NaN
# XX-P987             NaN              NaN        NaN
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P001        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P048  UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE ...   Sí
# XX-P091         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P092         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P093         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# ...                                                    ...  ...
# XX-P983        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P984        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P985        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P986        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí
# XX-P987  UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE ...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P001 2020-03-23 00:00:00.000                 NaN
# XX-P048 2020-03-24 00:00:00.000                 NaN
# XX-P091 2020-03-24 00:00:00.000                 NaN
# XX-P092 2020-03-24 00:00:00.000                 NaN
# XX-P093 2020-03-24 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P983 2020-04-06 20:23:49.600                 NaN
# XX-P984 2020-04-06 20:32:11.789                 NaN
# XX-P985 2020-04-06 20:35:09.565                 NaN
# XX-P986 2020-04-06 20:37:40.503                 NaN
# XX-P987 2020-04-06 20:47:15.930                 NaN
#
# [69 rows x 19 columns]

# %% [markdown]
# Si queremos los registros que no están en escuelas privadas, es decir aquellos que vienen de instituciones de gobierno o universidades públicas, podemos usar el comando de negación `~` para obtener el conjunto complementario.

# %%
df[ ~df['Institución_origen'].isin(escuelas_privadas) ]
# Out:
#              Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P002   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P003   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P004   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P005   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P006   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                    ...              ...                       ...
# XX-P996   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P997   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P998   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999   Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P1000  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#           Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P002   Inhumación       2019-01-26  2018-12-12 00:00:00              NaT
# XX-P003   Inhumación       2019-01-26  2018-12-13 00:00:00              NaT
# XX-P004   Inhumación       2019-01-26  2018-12-14 00:00:00              NaT
# XX-P005   Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P006   Inhumación       2019-01-26  2018-12-16 00:00:00              NaT
# ...              ...              ...                  ...              ...
# XX-P996   Inhumación       2018-09-01                  S/D              NaT
# XX-P997   Inhumación       2018-09-01  2017-10-27 00:00:00              NaT
# XX-P998   Inhumación       2018-09-01  2018-08-18 00:00:00              NaT
# XX-P999   Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
# XX-P1000  Inhumación       2018-09-01  2018-05-29 00:00:00              NaT
#
#          Restos_tipo       Sexo  Edad Conocido_Desconocido Primer apellido  \
# ID
# XX-P002      Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P003      Cadáver  Masculino   NaN             Conocido            Cruz
# XX-P004      Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P005      Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P006      Cadáver  Masculino   NaN          Desconocido             NaN
# ...              ...        ...   ...                  ...             ...
# XX-P996      Cadáver  Masculino  42.0             Conocido          Flores
# XX-P997      Cadáver  Masculino  64.0             Conocido          Juárez
# XX-P998      Cadáver  Masculino   NaN          Desconocido             NaN
# XX-P999      Cadáver   Femenino   1.0          Desconocido             NaN
# XX-P1000     Cadáver  Masculino   NaN          Desconocido             NaN
#
#          Segundo Apellido    Nombre(s)            Nombre completo  \
# ID
# XX-P002               NaN          NaN
# XX-P003            Lucero      Alberto        Alberto Cruz Lucero
# XX-P004               NaN          NaN
# XX-P005               NaN          NaN
# XX-P006               NaN          NaN
# ...                   ...          ...                        ...
# XX-P996           Rosette       Sergio      Sergio Flores Rosette
# XX-P997            Chávez  Juan Carlos  Juan Carlos Juárez Chávez
# XX-P998               NaN          NaN
# XX-P999               NaN          NaN
# XX-P1000              NaN          NaN
#
#                                          Institución_origen Rdoc  \
# ID
# XX-P002   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P003   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P004   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P005   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P006   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                     ...  ...
# XX-P996   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P997   UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P998   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999   INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P1000  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                   Marca_temporal  Datos alternativos
# ID
# XX-P002  2020-03-23 00:00:00.000                 NaN
# XX-P003  2020-03-23 00:00:00.000                 NaN
# XX-P004  2020-03-23 00:00:00.000                 NaN
# XX-P005  2020-03-23 00:00:00.000                 NaN
# XX-P006  2020-03-23 00:00:00.000                 NaN
# ...                          ...                 ...
# XX-P996  2020-04-06 21:19:52.451                 NaN
# XX-P997  2020-04-06 21:22:53.304                 NaN
# XX-P998  2020-04-06 21:30:12.169                 NaN
# XX-P999  2020-04-06 21:32:30.839                 NaN
# XX-P1000 2020-04-06 21:35:23.157                 NaN
#
# [931 rows x 19 columns]

# %% [markdown]
# Se pueden usar varias condiciones al mismo tiempo.
# Para combinar varias condiciones es necesario poner cada condición entre parentesis.
# Las condiciones se unen usando los operadores booleanos:
# * _&_ se cumplen ambas condiciones
# * _|_ se cumple al menos una de las condiciones
# * _~_ negación
#
# Por ejemplo, para seleccionar los restos de mujeres menores de 18 años ponemos cada uno de los selectores de edades antes visto entre paréntesis y los unimos con _&_

# %%
# df.loc[ (seleccionar_mujeres) & (seleccionar_menores_de_edad)] 
df.loc[  ( df['Sexo']=='Femenino' ) | ( df['Edad']<18 ) ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P014  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P019  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P027  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P034  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P037  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P956  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P967  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P968  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P969  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P014  Inhumación       2019-01-26  2018-12-19 00:00:00              NaT
# XX-P019  Inhumación       2019-01-26  2018-12-18 00:00:00              NaT
# XX-P027  Inhumación       2019-01-26                  S/D              NaT
# XX-P034  Inhumación       2019-01-19  2018-12-04 00:00:00              NaT
# XX-P037  Inhumación       2019-01-19  2018-12-07 00:00:00              NaT
# ...             ...              ...                  ...              ...
# XX-P956  Inhumación       2018-07-14  2018-06-09 00:00:00              NaT
# XX-P967  Inhumación       2018-07-14  2017-08-08 00:00:00              NaT
# XX-P968  Inhumación       2018-07-14  2017-07-21 00:00:00              NaT
# XX-P969  Inhumación       2018-07-14                  S/D              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#         Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P014     Cadáver   Femenino   NaN             Conocido
# XX-P019     Cadáver   Femenino   NaN             Conocido
# XX-P027    Miembros   Femenino  35.0             Conocido
# XX-P034     Cadáver   Femenino   NaN          Desconocido
# XX-P037     Cadáver   Femenino   NaN             Conocido
# ...             ...        ...   ...                  ...
# XX-P956     Cadáver   Femenino   NaN             Conocido
# XX-P967     Cadáver   Femenino   NaN          Desconocido
# XX-P968     Cadáver   Femenino   NaN             Conocido
# XX-P969    Miembros  Masculino   5.0             Conocido
# XX-P999     Cadáver   Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P014                                             Ibarra
# XX-P019                                           Martínez
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                           González
# ...                                                    ...
# XX-P956                                      Martha Helida
# XX-P967                                                NaN
# XX-P968                                             Gaytan
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P014                                             García
# XX-P019                                          Hernández
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                              Valle
# ...                                                    ...
# XX-P956                                              Silva
# XX-P967                                                NaN
# XX-P968                                            Ramirez
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P014                                              Wendy
# XX-P019                                              Adela
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034                                                NaN
# XX-P037                                             Gloria
# ...                                                    ...
# XX-P956                                            Morales
# XX-P967                                                NaN
# XX-P968                                            Marysol
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P014                                Wendy Ibarra García
# XX-P019                           Adela Martínez Hernández
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P034
# XX-P037                              Gloria González Valle
# ...                                                    ...
# XX-P956                        Morales Martha Helida Silva
# XX-P967
# XX-P968                             Marysol Gaytan Ramirez
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P014  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P019  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P027  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P034  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P037  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                    ...  ...
# XX-P956  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P967  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P968  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P969  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P014 2020-03-23 00:00:00.000                 NaN
# XX-P019 2020-03-23 00:00:00.000                 NaN
# XX-P027 2020-03-23 00:00:00.000                 NaN
# XX-P034 2020-03-23 00:00:00.000                 NaN
# XX-P037 2020-03-23 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P956 2020-04-06 11:09:46.318                 NaN
# XX-P967 2020-04-06 15:14:11.685                 NaN
# XX-P968 2020-04-06 15:17:22.421                 NaN
# XX-P969 2020-04-06 17:53:48.782                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN
#
# [176 rows x 19 columns]

# %% [markdown]
# Es posible hacer combinaciones de selecciones bastante complicadas, sin embargo se recomienda guardarlas en un dataframe específico e ir haciendo las selecciones por pasos.

# %%
df_vulnerables = df[ ~df['Edad'].isna() ] #ignorar aquellos que no tienen edad
# seleccionar menores de edad o mujeres, nota como seleccionamos sobre la primera seleccion y no el dataframe en general
df_vulnerables = df_vulnerables[ (df_vulnerables['Edad']<18) | (df_vulnerables['Sexo']=='Femenino') ]
df_vulnerables #ver el resultado
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P027  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P072  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P094  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P111  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P114  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P939  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P941  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P945  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P969  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P027  Inhumación       2019-01-26                  S/D              NaT
# XX-P072  Inhumación       2019-01-02  2017-08-16 00:00:00              NaT
# XX-P094  Inhumación       2018-12-08  2018-04-05 00:00:00              NaT
# XX-P111  Inhumación       2018-12-08  2018-12-11 00:00:00              NaT
# XX-P114  Inhumación       2018-12-08                  S/D              NaT
# ...             ...              ...                  ...              ...
# XX-P939  Inhumación       2018-07-07  2017-01-27 00:00:00              NaT
# XX-P941  Inhumación       2018-07-07  2017-02-07 00:00:00              NaT
# XX-P945  Inhumación       2018-07-07  2017-02-21 00:00:00              NaT
# XX-P969  Inhumación       2018-07-14                  S/D              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#              Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P027         Miembros   Femenino  35.0             Conocido
# XX-P072          Cadáver   Femenino  83.0             Conocido
# XX-P094          Cadáver   Femenino  40.0          Desconocido
# XX-P111          Cadáver   Femenino  35.0          Desconocido
# XX-P114         Miembros   Femenino  90.0             Conocido
# ...                  ...        ...   ...                  ...
# XX-P939  Restos cremados   Femenino  82.0             Conocido
# XX-P941  Restos cremados   Femenino  85.0             Conocido
# XX-P945  Restos cremados   Femenino  83.0             Conocido
# XX-P969         Miembros  Masculino   5.0             Conocido
# XX-P999          Cadáver   Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                               Luna
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                            Torices
# XX-P941                                          Domíngues
# XX-P945                                           Bautista
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                            Sanchez
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                             Tinoco
# XX-P941                                             Vargas
# XX-P945                                                NaN
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                      Maria Antonia
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                              Juana
# XX-P941                                              María
# XX-P945                                       Martha Elena
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                         Maria Antonia Luna Sanchez
# XX-P094
# XX-P111
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                               Juana Torices Tinoco
# XX-P941                             María Domíngues Vargas
# XX-P945                             Martha Elena Bautista
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P027  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P072  INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# XX-P094  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P111  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P114  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                    ...  ...
# XX-P939  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P941  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P945  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P969  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P027 2020-03-23 00:00:00.000                 NaN
# XX-P072 2020-03-24 00:00:00.000                 NaN
# XX-P094 2020-03-24 00:00:00.000                 NaN
# XX-P111 2020-03-24 00:00:00.000                 NaN
# XX-P114 2020-03-24 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P939 2020-04-06 02:43:06.361                 NaN
# XX-P941 2020-04-06 02:46:43.724                 NaN
# XX-P945 2020-04-06 09:03:36.324                 NaN
# XX-P969 2020-04-06 17:53:48.782                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN
#
# [120 rows x 19 columns]

# %% [markdown]
# Nota sobre fechas
#
# Algunos tipos de datos permiten realizar operaciones especializadas. Por ejemplo con las fechas se pueden extraes el mes, día, día de la semana, hora, etc. Veremos esto más adelante pero dejamos un ejemplo de registros inhumados en viernes.

# %%
df[ df['Fecha_inhumación'].dt.day_name() == 'Friday' ]
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P091  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P092  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P093  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P116  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P117  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P818  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P819  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P820  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P821  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P987  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P091  Inhumación       2018-12-14  2018-02-27 00:00:00              NaT
# XX-P092  Inhumación       2018-12-14  2018-03-22 00:00:00              NaT
# XX-P093  Inhumación       2018-12-14  2018-06-14 00:00:00              NaT
# XX-P116  Inhumación       2018-12-07  2017-11-13 00:00:00              NaT
# XX-P117  Inhumación       2018-12-07  2017-11-24 00:00:00              NaT
# ...             ...              ...                  ...              ...
# XX-P818  Inhumación       2017-10-06  2014-01-28 00:00:00              NaT
# XX-P819  Inhumación       2017-10-06  2014-01-30 00:00:00              NaT
# XX-P820  Inhumación       2017-10-06  2014-02-07 00:00:00              NaT
# XX-P821  Inhumación       2017-10-06  2014-02-09 00:00:00              NaT
# XX-P987  Inhumación       2017-07-28  2016-09-29 00:00:00              NaT
#
#         Restos_tipo       Sexo  Edad Conocido_Desconocido Primer apellido  \
# ID
# XX-P091     Cadáver  Masculino  40.0          Desconocido             NaN
# XX-P092     Cadáver  Masculino  40.0          Desconocido             NaN
# XX-P093     Cadáver  Masculino  40.0          Desconocido             NaN
# XX-P116     Cadáver   Femenino  76.0             Conocido         Belmont
# XX-P117     Cadáver   Femenino  84.0             Conocido         Huescas
# ...             ...        ...   ...                  ...             ...
# XX-P818     Cadáver  Masculino  73.0             Conocido         Alegria
# XX-P819     Cadáver  Masculino  75.0             Conocido           López
# XX-P820     Cadáver   Femenino  81.0             Conocido          Servin
# XX-P821     Cadáver  Masculino  54.0             Conocido       Rodríguez
# XX-P987     Cadáver  Masculino  65.0          Desconocido             NaN
#
#         Segundo Apellido  Nombre(s)                Nombre completo  \
# ID
# XX-P091              NaN        NaN
# XX-P092              NaN        NaN
# XX-P093              NaN        NaN
# XX-P116            López     Raquel           Raquel Belmont López
# XX-P117          Delgado   Lucresia       Lucresia Huescas Delgado
# ...                  ...        ...                            ...
# XX-P818      Castillejos  Silvestre  Silvestre Alegria Castillejos
# XX-P819           Eladio     Maximo            Maximo López Eladio
# XX-P820         Valverde     Elvira         Elvira Servin Valverde
# XX-P821          Zaracai     Efraín       Efraín Rodríguez Zaracai
# XX-P987              NaN        NaN
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P091         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P092         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P093         CENTRO CULTURAL UNIVERSITARIO JUSTO SIERRA   Sí
# XX-P116  INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# XX-P117  INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# ...                                                    ...  ...
# XX-P818  UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA   Sí
# XX-P819  UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA   Sí
# XX-P820  UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA   Sí
# XX-P821  UNIVERSIDAD POPULAR AUTÓNOMA DEL ESTADO DE PUEBLA   Sí
# XX-P987  UNIVERSIDAD TOMINAGA NAKAMOTO S.C. ESCUELA DE ...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P091 2020-03-24 00:00:00.000                 NaN
# XX-P092 2020-03-24 00:00:00.000                 NaN
# XX-P093 2020-03-24 00:00:00.000                 NaN
# XX-P116 2020-03-24 00:00:00.000                 NaN
# XX-P117 2020-03-24 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P818 2020-01-04 12:39:31.000                 NaN
# XX-P819 2020-01-04 12:44:52.000                 NaN
# XX-P820 2020-01-04 14:23:58.000                 NaN
# XX-P821 2020-01-04 14:49:07.000                 NaN
# XX-P987 2020-04-06 20:47:15.930                 NaN
#
# [67 rows x 19 columns]

# %% [markdown]
# ### Ejercicio 3
#
# * Escribe tres combinaciones de datos que te interesaria conocer y escribelas. Por ejemplo los restos recibidos en enero.
# * Tratá de resolver estas combinaciones de datos usando pandas. En caso de no poder anota que datos u operaciones hacen falta.
# * Escribe tres formas en las que te gustaría ordenar los datos.
# * Obten las tablas ordenadas, en caso de no poder hacerlo indica que datos te harían falta.

# %% [markdown]
# ## 3.f Guardar datos
#
# Ya que tienen un subset, es posible guardarlo para utilizarlo mas adelante o abrirlo en otro programa como excel.
#
# La nueva tabla debé de estar en una variable, en este caso usaremos `df_vulnerables`

# %%
df_vulnerables
# Out:
#             Estado_origen Municipio_origen            Panteón_origen  \
# ID
# XX-P027  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P072  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P094  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P111  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P114  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# ...                   ...              ...                       ...
# XX-P939  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P941  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P945  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P969  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
# XX-P999  Ciudad de México   Miguel Hidalgo  Panteón Civil de Dolores
#
#          Estatus_FC Fecha_inhumación      Fecha_defunción Fecha_exhumación  \
# ID
# XX-P027  Inhumación       2019-01-26                  S/D              NaT
# XX-P072  Inhumación       2019-01-02  2017-08-16 00:00:00              NaT
# XX-P094  Inhumación       2018-12-08  2018-04-05 00:00:00              NaT
# XX-P111  Inhumación       2018-12-08  2018-12-11 00:00:00              NaT
# XX-P114  Inhumación       2018-12-08                  S/D              NaT
# ...             ...              ...                  ...              ...
# XX-P939  Inhumación       2018-07-07  2017-01-27 00:00:00              NaT
# XX-P941  Inhumación       2018-07-07  2017-02-07 00:00:00              NaT
# XX-P945  Inhumación       2018-07-07  2017-02-21 00:00:00              NaT
# XX-P969  Inhumación       2018-07-14                  S/D              NaT
# XX-P999  Inhumación       2018-09-01  2018-05-22 00:00:00              NaT
#
#              Restos_tipo       Sexo  Edad Conocido_Desconocido  \
# ID
# XX-P027         Miembros   Femenino  35.0             Conocido
# XX-P072          Cadáver   Femenino  83.0             Conocido
# XX-P094          Cadáver   Femenino  40.0          Desconocido
# XX-P111          Cadáver   Femenino  35.0          Desconocido
# XX-P114         Miembros   Femenino  90.0             Conocido
# ...                  ...        ...   ...                  ...
# XX-P939  Restos cremados   Femenino  82.0             Conocido
# XX-P941  Restos cremados   Femenino  85.0             Conocido
# XX-P945  Restos cremados   Femenino  83.0             Conocido
# XX-P969         Miembros  Masculino   5.0             Conocido
# XX-P999          Cadáver   Femenino   1.0          Desconocido
#
#                                            Primer apellido  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                               Luna
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                            Torices
# XX-P941                                          Domíngues
# XX-P945                                           Bautista
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                           Segundo Apellido  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                            Sanchez
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                             Tinoco
# XX-P941                                             Vargas
# XX-P945                                                NaN
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                                  Nombre(s)  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                                      Maria Antonia
# XX-P094                                                NaN
# XX-P111                                                NaN
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                                              Juana
# XX-P941                                              María
# XX-P945                                       Martha Elena
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999                                                NaN
#
#                                            Nombre completo  \
# ID
# XX-P027  Nombre de particular que se encuentra con vida...
# XX-P072                         Maria Antonia Luna Sanchez
# XX-P094
# XX-P111
# XX-P114  Nombre de particular que se encuentra con vida...
# ...                                                    ...
# XX-P939                               Juana Torices Tinoco
# XX-P941                             María Domíngues Vargas
# XX-P945                             Martha Elena Bautista
# XX-P969  Nombre de particular que se encuentra con vida...
# XX-P999
#
#                                         Institución_origen Rdoc  \
# ID
# XX-P027  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P072  INSTITUTO POLITÉCNICO NACIONAL - ESCUELA NACIO...   Sí
# XX-P094  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P111  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P114  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# ...                                                    ...  ...
# XX-P939  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P941  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P945  UNIVERSIDAD NACIONAL AUTÓNOMA DE MÉXICO - FACU...   Sí
# XX-P969  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
# XX-P999  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí
#
#                  Marca_temporal  Datos alternativos
# ID
# XX-P027 2020-03-23 00:00:00.000                 NaN
# XX-P072 2020-03-24 00:00:00.000                 NaN
# XX-P094 2020-03-24 00:00:00.000                 NaN
# XX-P111 2020-03-24 00:00:00.000                 NaN
# XX-P114 2020-03-24 00:00:00.000                 NaN
# ...                         ...                 ...
# XX-P939 2020-04-06 02:43:06.361                 NaN
# XX-P941 2020-04-06 02:46:43.724                 NaN
# XX-P945 2020-04-06 09:03:36.324                 NaN
# XX-P969 2020-04-06 17:53:48.782                 NaN
# XX-P999 2020-04-06 21:32:30.839                 NaN
#
# [120 rows x 19 columns]

# %% [markdown]
# Después, decidiremos el nombre del archivo y lo guardaremos en una variable con el nombre del archivo de salida.
#
# Finalmente, exportaremos la tabla en formato `.csv` con `.to_csv()`. Esta función tiene varios parametros, los cuales incluyen el nombre del archivo de salida, el incluir o no el indice, etc. Estas pueden ser vistas en la documentación.

# %%
out_file = "data_clean/MFC_GruposVulnerables.csv"
df_vulnerables.to_csv(out_file)

# %% [markdown]
# **Gracias!**
